# %%
# To silence warnings

import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd

# %%
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("laptop_price.csv", encoding="latin-1")

# %%
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# 2               Notebook    15.6                           Full HD 1920x1080
# 3              Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 4              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...                  ...     ...                                         ...
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1301            Notebook    15.6                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1303 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
df.describe(include = 'all').T
# Out:
#                    count unique                         top  freq  \
# laptop_ID         1303.0    NaN                         NaN   NaN
# Company             1303     19                        Dell   297
# Product             1303    618                      XPS 13    30
# TypeName            1303      6                    Notebook   727
# Inches            1303.0    NaN                         NaN   NaN
# ScreenResolution    1303     40           Full HD 1920x1080   507
# Cpu                 1303    118  Intel Core i5 7200U 2.5GHz   190
# Ram                 1303      9                         8GB   619
# Memory              1303     39                   256GB SSD   412
# Gpu                 1303    110       Intel HD Graphics 620   281
# OpSys               1303      9                  Windows 10  1072
# Weight              1303    179                       2.2kg   121
# Price_euros       1303.0    NaN                         NaN   NaN
#
#                          mean         std    min    25%    50%      75%  \
# laptop_ID          660.155794  381.172104    1.0  331.5  659.0    990.5
# Company                   NaN         NaN    NaN    NaN    NaN      NaN
# Product                   NaN         NaN    NaN    NaN    NaN      NaN
# TypeName                  NaN         NaN    NaN    NaN    NaN      NaN
# Inches              15.017191    1.426304   10.1   14.0   15.6     15.6
# ScreenResolution          NaN         NaN    NaN    NaN    NaN      NaN
# Cpu                       NaN         NaN    NaN    NaN    NaN      NaN
# Ram                       NaN         NaN    NaN    NaN    NaN      NaN
# Memory                    NaN         NaN    NaN    NaN    NaN      NaN
# Gpu                       NaN         NaN    NaN    NaN    NaN      NaN
# OpSys                     NaN         NaN    NaN    NaN    NaN      NaN
# Weight                    NaN         NaN    NaN    NaN    NaN      NaN
# Price_euros       1123.686992  699.009043  174.0  599.0  977.0  1487.88
#
#                      max
# laptop_ID         1320.0
# Company              NaN
# Product              NaN
# TypeName             NaN
# Inches              18.4
# ScreenResolution     NaN
# Cpu                  NaN
# Ram                  NaN
# Memory               NaN
# Gpu                  NaN
# OpSys                NaN
# Weight               NaN
# Price_euros       6099.0

# %%
df = df.drop("Product", axis=1)

# %%
df = df.join(pd.get_dummies(df.Company))
df = df.drop("Company", axis=1)

# %%
df = df.join(pd.get_dummies(df.TypeName))
df = df.drop("TypeName", axis=1)

# %%
df
# Out:
#       laptop_ID  Inches                            ScreenResolution  \
# 0             1    13.3          IPS Panel Retina Display 2560x1600
# 1             2    13.3                                    1440x900
# 2             3    15.6                           Full HD 1920x1080
# 3             4    15.4          IPS Panel Retina Display 2880x1800
# 4             5    13.3          IPS Panel Retina Display 2560x1600
# ...         ...     ...                                         ...
# 1298       1316    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299       1317    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300       1318    14.0                                    1366x768
# 1301       1319    15.6                                    1366x768
# 1302       1320    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros   Acer  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69  False
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94  False
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00  False
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45  False
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60  False
# ...                            ...         ...     ...          ...    ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00  False
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00  False
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00  False
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00  False
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00  False
#
#       Apple   Asus  Chuwi   Dell  Fujitsu  Google     HP  Huawei     LG  \
# 0      True  False  False  False    False   False  False   False  False
# 1      True  False  False  False    False   False  False   False  False
# 2     False  False  False  False    False   False   True   False  False
# 3      True  False  False  False    False   False  False   False  False
# 4      True  False  False  False    False   False  False   False  False
# ...     ...    ...    ...    ...      ...     ...    ...     ...    ...
# 1298  False  False  False  False    False   False  False   False  False
# 1299  False  False  False  False    False   False  False   False  False
# 1300  False  False  False  False    False   False  False   False  False
# 1301  False  False  False  False    False   False   True   False  False
# 1302  False   True  False  False    False   False  False   False  False
#
#       Lenovo    MSI  Mediacom  Microsoft  Razer  Samsung  Toshiba   Vero  \
# 0      False  False     False      False  False    False    False  False
# 1      False  False     False      False  False    False    False  False
# 2      False  False     False      False  False    False    False  False
# 3      False  False     False      False  False    False    False  False
# 4      False  False     False      False  False    False    False  False
# ...      ...    ...       ...        ...    ...      ...      ...    ...
# 1298    True  False     False      False  False    False    False  False
# 1299    True  False     False      False  False    False    False  False
# 1300    True  False     False      False  False    False    False  False
# 1301   False  False     False      False  False    False    False  False
# 1302   False  False     False      False  False    False    False  False
#
#       Xiaomi  2 in 1 Convertible  Gaming  Netbook  Notebook  Ultrabook  \
# 0      False               False   False    False     False       True
# 1      False               False   False    False     False       True
# 2      False               False   False    False      True      False
# 3      False               False   False    False     False       True
# 4      False               False   False    False     False       True
# ...      ...                 ...     ...      ...       ...        ...
# 1298   False                True   False    False     False      False
# 1299   False                True   False    False     False      False
# 1300   False               False   False    False      True      False
# 1301   False               False   False    False      True      False
# 1302   False               False   False    False      True      False
#
#       Workstation
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 1298        False
# 1299        False
# 1300        False
# 1301        False
# 1302        False
#
# [1303 rows x 35 columns]

# %%
df["ScreenResolution"] = df.ScreenResolution.str.split(" ").apply(lambda x: x[-1])
df["Screen Width"] = df.ScreenResolution.str.split("x").apply(lambda x: x[0])
df["Screen Height"] = df.ScreenResolution.str.split("x").apply(lambda x: x[1])

# %%
df = df.drop("ScreenResolution", axis=1)

# %%
df
# Out:
#       laptop_ID  Inches                                   Cpu   Ram  \
# 0             1    13.3                  Intel Core i5 2.3GHz   8GB
# 1             2    13.3                  Intel Core i5 1.8GHz   8GB
# 2             3    15.6            Intel Core i5 7200U 2.5GHz   8GB
# 3             4    15.4                  Intel Core i7 2.7GHz  16GB
# 4             5    13.3                  Intel Core i5 3.1GHz   8GB
# ...         ...     ...                                   ...   ...
# 1298       1316    14.0            Intel Core i7 6500U 2.5GHz   4GB
# 1299       1317    13.3            Intel Core i7 6500U 2.5GHz  16GB
# 1300       1318    14.0  Intel Celeron Dual Core N3050 1.6GHz   2GB
# 1301       1319    15.6            Intel Core i7 6500U 2.5GHz   6GB
# 1302       1320    15.6  Intel Celeron Dual Core N3050 1.6GHz   4GB
#
#                    Memory                           Gpu       OpSys  Weight  \
# 0               128GB SSD  Intel Iris Plus Graphics 640       macOS  1.37kg
# 1     128GB Flash Storage        Intel HD Graphics 6000       macOS  1.34kg
# 2               256GB SSD         Intel HD Graphics 620       No OS  1.86kg
# 3               512GB SSD            AMD Radeon Pro 455       macOS  1.83kg
# 4               256GB SSD  Intel Iris Plus Graphics 650       macOS  1.37kg
# ...                   ...                           ...         ...     ...
# 1298            128GB SSD         Intel HD Graphics 520  Windows 10   1.8kg
# 1299            512GB SSD         Intel HD Graphics 520  Windows 10   1.3kg
# 1300   64GB Flash Storage             Intel HD Graphics  Windows 10   1.5kg
# 1301              1TB HDD            AMD Radeon R5 M330  Windows 10  2.19kg
# 1302            500GB HDD             Intel HD Graphics  Windows 10   2.2kg
#
#       Price_euros   Acer  Apple   Asus  Chuwi   Dell  Fujitsu  Google     HP  \
# 0         1339.69  False   True  False  False  False    False   False  False
# 1          898.94  False   True  False  False  False    False   False  False
# 2          575.00  False  False  False  False  False    False   False   True
# 3         2537.45  False   True  False  False  False    False   False  False
# 4         1803.60  False   True  False  False  False    False   False  False
# ...           ...    ...    ...    ...    ...    ...      ...     ...    ...
# 1298       638.00  False  False  False  False  False    False   False  False
# 1299      1499.00  False  False  False  False  False    False   False  False
# 1300       229.00  False  False  False  False  False    False   False  False
# 1301       764.00  False  False  False  False  False    False   False   True
# 1302       369.00  False  False   True  False  False    False   False  False
#
#       Huawei     LG  Lenovo    MSI  Mediacom  Microsoft  Razer  Samsung  \
# 0      False  False   False  False     False      False  False    False
# 1      False  False   False  False     False      False  False    False
# 2      False  False   False  False     False      False  False    False
# 3      False  False   False  False     False      False  False    False
# 4      False  False   False  False     False      False  False    False
# ...      ...    ...     ...    ...       ...        ...    ...      ...
# 1298   False  False    True  False     False      False  False    False
# 1299   False  False    True  False     False      False  False    False
# 1300   False  False    True  False     False      False  False    False
# 1301   False  False   False  False     False      False  False    False
# 1302   False  False   False  False     False      False  False    False
#
#       Toshiba   Vero  Xiaomi  2 in 1 Convertible  Gaming  Netbook  Notebook  \
# 0       False  False   False               False   False    False     False
# 1       False  False   False               False   False    False     False
# 2       False  False   False               False   False    False      True
# 3       False  False   False               False   False    False     False
# 4       False  False   False               False   False    False     False
# ...       ...    ...     ...                 ...     ...      ...       ...
# 1298    False  False   False                True   False    False     False
# 1299    False  False   False                True   False    False     False
# 1300    False  False   False               False   False    False      True
# 1301    False  False   False               False   False    False      True
# 1302    False  False   False               False   False    False      True
#
#       Ultrabook  Workstation Screen Width Screen Height
# 0          True        False         2560          1600
# 1          True        False         1440           900
# 2         False        False         1920          1080
# 3          True        False         2880          1800
# 4          True        False         2560          1600
# ...         ...          ...          ...           ...
# 1298      False        False         1920          1080
# 1299      False        False         3200          1800
# 1300      False        False         1366           768
# 1301      False        False         1366           768
# 1302      False        False         1366           768
#
# [1303 rows x 36 columns]

# %%
df["CPU Brand"] = df.Cpu.str.split(" ").apply(lambda x: x[0])
df["CPU Frequency"] = df.Cpu.str.split(" ").apply(lambda x: x[-1])

# %%
df = df.drop("Cpu", axis=1)

# %%
df["CPU Frequency"] = df["CPU Frequency"].str[:-3]

# %%
df["Ram"] = df["Ram"].str[:-2]

# %%
df["Ram"] = df["Ram"].astype("int")
df["CPU Frequency"] = df["CPU Frequency"].astype("float")

# %%
df["Screen Width"] = df["Screen Width"].astype("int")
df["Screen Height"] = df["Screen Height"].astype("int")

# %%
df
# Out:
#       laptop_ID  Inches  Ram               Memory  \
# 0             1    13.3    8            128GB SSD
# 1             2    13.3    8  128GB Flash Storage
# 2             3    15.6    8            256GB SSD
# 3             4    15.4   16            512GB SSD
# 4             5    13.3    8            256GB SSD
# ...         ...     ...  ...                  ...
# 1298       1316    14.0    4            128GB SSD
# 1299       1317    13.3   16            512GB SSD
# 1300       1318    14.0    2   64GB Flash Storage
# 1301       1319    15.6    6              1TB HDD
# 1302       1320    15.6    4            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros   Acer  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69  False
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94  False
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00  False
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45  False
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60  False
# ...                            ...         ...     ...          ...    ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00  False
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00  False
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00  False
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00  False
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00  False
#
#       Apple   Asus  Chuwi   Dell  Fujitsu  Google     HP  Huawei     LG  \
# 0      True  False  False  False    False   False  False   False  False
# 1      True  False  False  False    False   False  False   False  False
# 2     False  False  False  False    False   False   True   False  False
# 3      True  False  False  False    False   False  False   False  False
# 4      True  False  False  False    False   False  False   False  False
# ...     ...    ...    ...    ...      ...     ...    ...     ...    ...
# 1298  False  False  False  False    False   False  False   False  False
# 1299  False  False  False  False    False   False  False   False  False
# 1300  False  False  False  False    False   False  False   False  False
# 1301  False  False  False  False    False   False   True   False  False
# 1302  False   True  False  False    False   False  False   False  False
#
#       Lenovo    MSI  Mediacom  Microsoft  Razer  Samsung  Toshiba   Vero  \
# 0      False  False     False      False  False    False    False  False
# 1      False  False     False      False  False    False    False  False
# 2      False  False     False      False  False    False    False  False
# 3      False  False     False      False  False    False    False  False
# 4      False  False     False      False  False    False    False  False
# ...      ...    ...       ...        ...    ...      ...      ...    ...
# 1298    True  False     False      False  False    False    False  False
# 1299    True  False     False      False  False    False    False  False
# 1300    True  False     False      False  False    False    False  False
# 1301   False  False     False      False  False    False    False  False
# 1302   False  False     False      False  False    False    False  False
#
#       Xiaomi  2 in 1 Convertible  Gaming  Netbook  Notebook  Ultrabook  \
# 0      False               False   False    False     False       True
# 1      False               False   False    False     False       True
# 2      False               False   False    False      True      False
# 3      False               False   False    False     False       True
# 4      False               False   False    False     False       True
# ...      ...                 ...     ...      ...       ...        ...
# 1298   False                True   False    False     False      False
# 1299   False                True   False    False     False      False
# 1300   False               False   False    False      True      False
# 1301   False               False   False    False      True      False
# 1302   False               False   False    False      True      False
#
#       Workstation  Screen Width  Screen Height CPU Brand  CPU Frequency
# 0           False          2560           1600     Intel            2.3
# 1           False          1440            900     Intel            1.8
# 2           False          1920           1080     Intel            2.5
# 3           False          2880           1800     Intel            2.7
# 4           False          2560           1600     Intel            3.1
# ...           ...           ...            ...       ...            ...
# 1298        False          1920           1080     Intel            2.5
# 1299        False          3200           1800     Intel            2.5
# 1300        False          1366            768     Intel            1.6
# 1301        False          1366            768     Intel            2.5
# 1302        False          1366            768     Intel            1.6
#
# [1303 rows x 37 columns]

# %%
df["CPU Brand"].value_counts()
# Out:
# CPU Brand
# Intel      1240
# AMD          62
# Samsung       1
# Name: count, dtype: int64

# %%
df["Memory Amount"] = df.Memory.str.split(" ").apply(lambda x: x[0])
df["Memory Type"] = df.Memory.str.split(" ").apply(lambda x: x[1])

# %%
def turn_memory_into_MB(value):
    if "GB" in value:
        return float(value[:value.find("GB")]) * 1000
    elif "TB" in value:
        return float(value[:value.find("TB")]) * 1000000

# %%
df["Memory Amount"] = df["Memory Amount"].apply(turn_memory_into_MB)

# %%
df = df.drop("Memory", axis=1)

# %%
df.head()
# Out:
#    laptop_ID  Inches  Ram                           Gpu  OpSys  Weight  \
# 0          1    13.3    8  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1          2    13.3    8        Intel HD Graphics 6000  macOS  1.34kg
# 2          3    15.6    8         Intel HD Graphics 620  No OS  1.86kg
# 3          4    15.4   16            AMD Radeon Pro 455  macOS  1.83kg
# 4          5    13.3    8  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros   Acer  Apple   Asus  Chuwi   Dell  Fujitsu  Google     HP  \
# 0      1339.69  False   True  False  False  False    False   False  False
# 1       898.94  False   True  False  False  False    False   False  False
# 2       575.00  False  False  False  False  False    False   False   True
# 3      2537.45  False   True  False  False  False    False   False  False
# 4      1803.60  False   True  False  False  False    False   False  False
#
#    Huawei     LG  Lenovo    MSI  Mediacom  Microsoft  Razer  Samsung  Toshiba  \
# 0   False  False   False  False     False      False  False    False    False
# 1   False  False   False  False     False      False  False    False    False
# 2   False  False   False  False     False      False  False    False    False
# 3   False  False   False  False     False      False  False    False    False
# 4   False  False   False  False     False      False  False    False    False
#
#     Vero  Xiaomi  2 in 1 Convertible  Gaming  Netbook  Notebook  Ultrabook  \
# 0  False   False               False   False    False     False       True
# 1  False   False               False   False    False     False       True
# 2  False   False               False   False    False      True      False
# 3  False   False               False   False    False     False       True
# 4  False   False               False   False    False     False       True
#
#    Workstation  Screen Width  Screen Height CPU Brand  CPU Frequency  \
# 0        False          2560           1600     Intel            2.3
# 1        False          1440            900     Intel            1.8
# 2        False          1920           1080     Intel            2.5
# 3        False          2880           1800     Intel            2.7
# 4        False          2560           1600     Intel            3.1
#
#    Memory Amount Memory Type
# 0       128000.0         SSD
# 1       128000.0       Flash
# 2       256000.0         SSD
# 3       512000.0         SSD
# 4       256000.0         SSD

# %%
df["Memory Type"].value_counts()
# Out:
# Memory Type
# SSD       843
# HDD       375
# Flash      75
# Hybrid     10
# Name: count, dtype: int64

# %%
df["Weight"] = df["Weight"].str[:-2]

# %%
df["Weight"] = df["Weight"].astype("float")

# %%
df["GPU Brand"] = df.Gpu.str.split(" ").apply(lambda x: x[0])

# %%
df = df.drop("Gpu", axis=1)

# %%
df = df.join(pd.get_dummies(df.OpSys))
df = df.drop("OpSys", axis=1)

# %%
cpu_categories = pd.get_dummies(df["CPU Brand"])

# %%
df.head()
# Out:
#    laptop_ID  Inches  Ram  Weight  Price_euros   Acer  Apple   Asus  Chuwi  \
# 0          1    13.3    8    1.37      1339.69  False   True  False  False
# 1          2    13.3    8    1.34       898.94  False   True  False  False
# 2          3    15.6    8    1.86       575.00  False  False  False  False
# 3          4    15.4   16    1.83      2537.45  False   True  False  False
# 4          5    13.3    8    1.37      1803.60  False   True  False  False
#
#     Dell  Fujitsu  Google     HP  Huawei     LG  Lenovo    MSI  Mediacom  \
# 0  False    False   False  False   False  False   False  False     False
# 1  False    False   False  False   False  False   False  False     False
# 2  False    False   False   True   False  False   False  False     False
# 3  False    False   False  False   False  False   False  False     False
# 4  False    False   False  False   False  False   False  False     False
#
#    Microsoft  Razer  Samsung  Toshiba   Vero  Xiaomi  2 in 1 Convertible  \
# 0      False  False    False    False  False   False               False
# 1      False  False    False    False  False   False               False
# 2      False  False    False    False  False   False               False
# 3      False  False    False    False  False   False               False
# 4      False  False    False    False  False   False               False
#
#    Gaming  Netbook  Notebook  Ultrabook  Workstation  Screen Width  \
# 0   False    False     False       True        False          2560
# 1   False    False     False       True        False          1440
# 2   False    False      True      False        False          1920
# 3   False    False     False       True        False          2880
# 4   False    False     False       True        False          2560
#
#    Screen Height CPU Brand  CPU Frequency  Memory Amount Memory Type  \
# 0           1600     Intel            2.3       128000.0         SSD
# 1            900     Intel            1.8       128000.0       Flash
# 2           1080     Intel            2.5       256000.0         SSD
# 3           1800     Intel            2.7       512000.0         SSD
# 4           1600     Intel            3.1       256000.0         SSD
#
#   GPU Brand  Android  Chrome OS  Linux  Mac OS X  No OS  Windows 10  \
# 0     Intel    False      False  False     False  False       False
# 1     Intel    False      False  False     False  False       False
# 2     Intel    False      False  False     False   True       False
# 3       AMD    False      False  False     False  False       False
# 4     Intel    False      False  False     False  False       False
#
#    Windows 10 S  Windows 7  macOS
# 0         False      False   True
# 1         False      False   True
# 2         False      False  False
# 3         False      False   True
# 4         False      False   True

# %%
# cpu_categories = pd.get_dummies(df["CPU Brand"])
cpu_categories.columns = [col + "_CPU" for col in cpu_categories.columns]

df = df.join(cpu_categories)
df = df.drop("CPU Brand", axis=1)

# %%
df
# Out:
#       laptop_ID  Inches  Ram  Weight  Price_euros   Acer  Apple   Asus  Chuwi  \
# 0             1    13.3    8    1.37      1339.69  False   True  False  False
# 1             2    13.3    8    1.34       898.94  False   True  False  False
# 2             3    15.6    8    1.86       575.00  False  False  False  False
# 3             4    15.4   16    1.83      2537.45  False   True  False  False
# 4             5    13.3    8    1.37      1803.60  False   True  False  False
# ...         ...     ...  ...     ...          ...    ...    ...    ...    ...
# 1298       1316    14.0    4    1.80       638.00  False  False  False  False
# 1299       1317    13.3   16    1.30      1499.00  False  False  False  False
# 1300       1318    14.0    2    1.50       229.00  False  False  False  False
# 1301       1319    15.6    6    2.19       764.00  False  False  False  False
# 1302       1320    15.6    4    2.20       369.00  False  False   True  False
#
#        Dell  Fujitsu  Google     HP  Huawei     LG  Lenovo    MSI  Mediacom  \
# 0     False    False   False  False   False  False   False  False     False
# 1     False    False   False  False   False  False   False  False     False
# 2     False    False   False   True   False  False   False  False     False
# 3     False    False   False  False   False  False   False  False     False
# 4     False    False   False  False   False  False   False  False     False
# ...     ...      ...     ...    ...     ...    ...     ...    ...       ...
# 1298  False    False   False  False   False  False    True  False     False
# 1299  False    False   False  False   False  False    True  False     False
# 1300  False    False   False  False   False  False    True  False     False
# 1301  False    False   False   True   False  False   False  False     False
# 1302  False    False   False  False   False  False   False  False     False
#
#       Microsoft  Razer  Samsung  Toshiba   Vero  Xiaomi  2 in 1 Convertible  \
# 0         False  False    False    False  False   False               False
# 1         False  False    False    False  False   False               False
# 2         False  False    False    False  False   False               False
# 3         False  False    False    False  False   False               False
# 4         False  False    False    False  False   False               False
# ...         ...    ...      ...      ...    ...     ...                 ...
# 1298      False  False    False    False  False   False                True
# 1299      False  False    False    False  False   False                True
# 1300      False  False    False    False  False   False               False
# 1301      False  False    False    False  False   False               False
# 1302      False  False    False    False  False   False               False
#
#       Gaming  Netbook  Notebook  Ultrabook  Workstation  Screen Width  \
# 0      False    False     False       True        False          2560
# 1      False    False     False       True        False          1440
# 2      False    False      True      False        False          1920
# 3      False    False     False       True        False          2880
# 4      False    False     False       True        False          2560
# ...      ...      ...       ...        ...          ...           ...
# 1298   False    False     False      False        False          1920
# 1299   False    False     False      False        False          3200
# 1300   False    False      True      False        False          1366
# 1301   False    False      True      False        False          1366
# 1302   False    False      True      False        False          1366
#
#       Screen Height  CPU Frequency  Memory Amount Memory Type GPU Brand  \
# 0              1600            2.3       128000.0         SSD     Intel
# 1               900            1.8       128000.0       Flash     Intel
# 2              1080            2.5       256000.0         SSD     Intel
# 3              1800            2.7       512000.0         SSD       AMD
# 4              1600            3.1       256000.0         SSD     Intel
# ...             ...            ...            ...         ...       ...
# 1298           1080            2.5       128000.0         SSD     Intel
# 1299           1800            2.5       512000.0         SSD     Intel
# 1300            768            1.6        64000.0       Flash     Intel
# 1301            768            2.5      1000000.0         HDD       AMD
# 1302            768            1.6       500000.0         HDD     Intel
#
#       Android  Chrome OS  Linux  Mac OS X  No OS  Windows 10  Windows 10 S  \
# 0       False      False  False     False  False       False         False
# 1       False      False  False     False  False       False         False
# 2       False      False  False     False   True       False         False
# 3       False      False  False     False  False       False         False
# 4       False      False  False     False  False       False         False
# ...       ...        ...    ...       ...    ...         ...           ...
# 1298    False      False  False     False  False        True         False
# 1299    False      False  False     False  False        True         False
# 1300    False      False  False     False  False        True         False
# 1301    False      False  False     False  False        True         False
# 1302    False      False  False     False  False        True         False
#
#       Windows 7  macOS  AMD_CPU  Intel_CPU  Samsung_CPU
# 0         False   True    False       True        False
# 1         False   True    False       True        False
# 2         False  False    False       True        False
# 3         False   True    False       True        False
# 4         False   True    False       True        False
# ...         ...    ...      ...        ...          ...
# 1298      False  False    False       True        False
# 1299      False  False    False       True        False
# 1300      False  False    False       True        False
# 1301      False  False    False       True        False
# 1302      False  False    False       True        False
#
# [1303 rows x 48 columns]

# %%
gpu_categories = pd.get_dummies(df["GPU Brand"])
gpu_categories.columns = [col + "_GPU" for col in gpu_categories.columns]

df = df.join(gpu_categories)
df = df.drop("GPU Brand", axis=1)

# %%
mem_type_categories = pd.get_dummies(df["Memory Type"])
mem_type_categories.columns = [col + "_MEM" for col in mem_type_categories.columns]

df = df.join(mem_type_categories)
df = df.drop("Memory Type", axis=1)

# %%
df
# Out:
#       laptop_ID  Inches  Ram  Weight  Price_euros   Acer  Apple   Asus  Chuwi  \
# 0             1    13.3    8    1.37      1339.69  False   True  False  False
# 1             2    13.3    8    1.34       898.94  False   True  False  False
# 2             3    15.6    8    1.86       575.00  False  False  False  False
# 3             4    15.4   16    1.83      2537.45  False   True  False  False
# 4             5    13.3    8    1.37      1803.60  False   True  False  False
# ...         ...     ...  ...     ...          ...    ...    ...    ...    ...
# 1298       1316    14.0    4    1.80       638.00  False  False  False  False
# 1299       1317    13.3   16    1.30      1499.00  False  False  False  False
# 1300       1318    14.0    2    1.50       229.00  False  False  False  False
# 1301       1319    15.6    6    2.19       764.00  False  False  False  False
# 1302       1320    15.6    4    2.20       369.00  False  False   True  False
#
#        Dell  Fujitsu  Google     HP  Huawei     LG  Lenovo    MSI  Mediacom  \
# 0     False    False   False  False   False  False   False  False     False
# 1     False    False   False  False   False  False   False  False     False
# 2     False    False   False   True   False  False   False  False     False
# 3     False    False   False  False   False  False   False  False     False
# 4     False    False   False  False   False  False   False  False     False
# ...     ...      ...     ...    ...     ...    ...     ...    ...       ...
# 1298  False    False   False  False   False  False    True  False     False
# 1299  False    False   False  False   False  False    True  False     False
# 1300  False    False   False  False   False  False    True  False     False
# 1301  False    False   False   True   False  False   False  False     False
# 1302  False    False   False  False   False  False   False  False     False
#
#       Microsoft  Razer  Samsung  Toshiba   Vero  Xiaomi  2 in 1 Convertible  \
# 0         False  False    False    False  False   False               False
# 1         False  False    False    False  False   False               False
# 2         False  False    False    False  False   False               False
# 3         False  False    False    False  False   False               False
# 4         False  False    False    False  False   False               False
# ...         ...    ...      ...      ...    ...     ...                 ...
# 1298      False  False    False    False  False   False                True
# 1299      False  False    False    False  False   False                True
# 1300      False  False    False    False  False   False               False
# 1301      False  False    False    False  False   False               False
# 1302      False  False    False    False  False   False               False
#
#       Gaming  Netbook  Notebook  Ultrabook  Workstation  Screen Width  \
# 0      False    False     False       True        False          2560
# 1      False    False     False       True        False          1440
# 2      False    False      True      False        False          1920
# 3      False    False     False       True        False          2880
# 4      False    False     False       True        False          2560
# ...      ...      ...       ...        ...          ...           ...
# 1298   False    False     False      False        False          1920
# 1299   False    False     False      False        False          3200
# 1300   False    False      True      False        False          1366
# 1301   False    False      True      False        False          1366
# 1302   False    False      True      False        False          1366
#
#       Screen Height  CPU Frequency  Memory Amount  Android  Chrome OS  Linux  \
# 0              1600            2.3       128000.0    False      False  False
# 1               900            1.8       128000.0    False      False  False
# 2              1080            2.5       256000.0    False      False  False
# 3              1800            2.7       512000.0    False      False  False
# 4              1600            3.1       256000.0    False      False  False
# ...             ...            ...            ...      ...        ...    ...
# 1298           1080            2.5       128000.0    False      False  False
# 1299           1800            2.5       512000.0    False      False  False
# 1300            768            1.6        64000.0    False      False  False
# 1301            768            2.5      1000000.0    False      False  False
# 1302            768            1.6       500000.0    False      False  False
#
#       Mac OS X  No OS  Windows 10  Windows 10 S  Windows 7  macOS  AMD_CPU  \
# 0        False  False       False         False      False   True    False
# 1        False  False       False         False      False   True    False
# 2        False   True       False         False      False  False    False
# 3        False  False       False         False      False   True    False
# 4        False  False       False         False      False   True    False
# ...        ...    ...         ...           ...        ...    ...      ...
# 1298     False  False        True         False      False  False    False
# 1299     False  False        True         False      False  False    False
# 1300     False  False        True         False      False  False    False
# 1301     False  False        True         False      False  False    False
# 1302     False  False        True         False      False  False    False
#
#       Intel_CPU  Samsung_CPU  AMD_GPU  ARM_GPU  Intel_GPU  Nvidia_GPU  \
# 0          True        False    False    False       True       False
# 1          True        False    False    False       True       False
# 2          True        False    False    False       True       False
# 3          True        False     True    False      False       False
# 4          True        False    False    False       True       False
# ...         ...          ...      ...      ...        ...         ...
# 1298       True        False    False    False       True       False
# 1299       True        False    False    False       True       False
# 1300       True        False    False    False       True       False
# 1301       True        False     True    False      False       False
# 1302       True        False    False    False       True       False
#
#       Flash_MEM  HDD_MEM  Hybrid_MEM  SSD_MEM
# 0         False    False       False     True
# 1          True    False       False    False
# 2         False    False       False     True
# 3         False    False       False     True
# 4         False    False       False     True
# ...         ...      ...         ...      ...
# 1298      False    False       False     True
# 1299      False    False       False     True
# 1300       True    False       False    False
# 1301      False     True       False    False
# 1302      False     True       False    False
#
# [1303 rows x 54 columns]

# %%
df.describe(include = 'all').T
# Out:
#                      count unique    top  freq           mean            std  \
# laptop_ID           1303.0    NaN    NaN   NaN     660.155794     381.172104
# Inches              1303.0    NaN    NaN   NaN      15.017191       1.426304
# Ram                 1303.0    NaN    NaN   NaN       8.382195       5.084665
# Weight              1303.0    NaN    NaN   NaN       2.038734       0.665475
# Price_euros         1303.0    NaN    NaN   NaN    1123.686992     699.009043
# Acer                  1303      2  False  1200            NaN            NaN
# Apple                 1303      2  False  1282            NaN            NaN
# Asus                  1303      2  False  1145            NaN            NaN
# Chuwi                 1303      2  False  1300            NaN            NaN
# Dell                  1303      2  False  1006            NaN            NaN
# Fujitsu               1303      2  False  1300            NaN            NaN
# Google                1303      2  False  1300            NaN            NaN
# HP                    1303      2  False  1029            NaN            NaN
# Huawei                1303      2  False  1301            NaN            NaN
# LG                    1303      2  False  1300            NaN            NaN
# Lenovo                1303      2  False  1006            NaN            NaN
# MSI                   1303      2  False  1249            NaN            NaN
# Mediacom              1303      2  False  1296            NaN            NaN
# Microsoft             1303      2  False  1297            NaN            NaN
# Razer                 1303      2  False  1296            NaN            NaN
# Samsung               1303      2  False  1294            NaN            NaN
# Toshiba               1303      2  False  1255            NaN            NaN
# Vero                  1303      2  False  1299            NaN            NaN
# Xiaomi                1303      2  False  1299            NaN            NaN
# 2 in 1 Convertible    1303      2  False  1182            NaN            NaN
# Gaming                1303      2  False  1098            NaN            NaN
# Netbook               1303      2  False  1278            NaN            NaN
# Notebook              1303      2   True   727            NaN            NaN
# Ultrabook             1303      2  False  1107            NaN            NaN
# Workstation           1303      2  False  1274            NaN            NaN
# Screen Width        1303.0    NaN    NaN   NaN    1894.784344     494.641028
# Screen Height       1303.0    NaN    NaN   NaN    1070.830391      284.51941
# CPU Frequency       1303.0    NaN    NaN   NaN       2.298772        0.50634
# Memory Amount       1303.0    NaN    NaN   NaN  442615.502686  356225.802118
# Android               1303      2  False  1301            NaN            NaN
# Chrome OS             1303      2  False  1276            NaN            NaN
# Linux                 1303      2  False  1241            NaN            NaN
# Mac OS X              1303      2  False  1295            NaN            NaN
# No OS                 1303      2  False  1237            NaN            NaN
# Windows 10            1303      2   True  1072            NaN            NaN
# Windows 10 S          1303      2  False  1295            NaN            NaN
# Windows 7             1303      2  False  1258            NaN            NaN
# macOS                 1303      2  False  1290            NaN            NaN
# AMD_CPU               1303      2  False  1241            NaN            NaN
# Intel_CPU             1303      2   True  1240            NaN            NaN
# Samsung_CPU           1303      2  False  1302            NaN            NaN
# AMD_GPU               1303      2  False  1123            NaN            NaN
# ARM_GPU               1303      2  False  1302            NaN            NaN
# Intel_GPU             1303      2   True   722            NaN            NaN
# Nvidia_GPU            1303      2  False   903            NaN            NaN
# Flash_MEM             1303      2  False  1228            NaN            NaN
# HDD_MEM               1303      2  False   928            NaN            NaN
# Hybrid_MEM            1303      2  False  1293            NaN            NaN
# SSD_MEM               1303      2   True   843            NaN            NaN
#
#                        min       25%       50%       75%        max
# laptop_ID              1.0     331.5     659.0     990.5     1320.0
# Inches                10.1      14.0      15.6      15.6       18.4
# Ram                    2.0       4.0       8.0       8.0       64.0
# Weight                0.69       1.5      2.04       2.3        4.7
# Price_euros          174.0     599.0     977.0   1487.88     6099.0
# Acer                   NaN       NaN       NaN       NaN        NaN
# Apple                  NaN       NaN       NaN       NaN        NaN
# Asus                   NaN       NaN       NaN       NaN        NaN
# Chuwi                  NaN       NaN       NaN       NaN        NaN
# Dell                   NaN       NaN       NaN       NaN        NaN
# Fujitsu                NaN       NaN       NaN       NaN        NaN
# Google                 NaN       NaN       NaN       NaN        NaN
# HP                     NaN       NaN       NaN       NaN        NaN
# Huawei                 NaN       NaN       NaN       NaN        NaN
# LG                     NaN       NaN       NaN       NaN        NaN
# Lenovo                 NaN       NaN       NaN       NaN        NaN
# MSI                    NaN       NaN       NaN       NaN        NaN
# Mediacom               NaN       NaN       NaN       NaN        NaN
# Microsoft              NaN       NaN       NaN       NaN        NaN
# Razer                  NaN       NaN       NaN       NaN        NaN
# Samsung                NaN       NaN       NaN       NaN        NaN
# Toshiba                NaN       NaN       NaN       NaN        NaN
# Vero                   NaN       NaN       NaN       NaN        NaN
# Xiaomi                 NaN       NaN       NaN       NaN        NaN
# 2 in 1 Convertible     NaN       NaN       NaN       NaN        NaN
# Gaming                 NaN       NaN       NaN       NaN        NaN
# Netbook                NaN       NaN       NaN       NaN        NaN
# Notebook               NaN       NaN       NaN       NaN        NaN
# Ultrabook              NaN       NaN       NaN       NaN        NaN
# Workstation            NaN       NaN       NaN       NaN        NaN
# Screen Width        1366.0    1600.0    1920.0    1920.0     3840.0
# Screen Height        768.0     900.0    1080.0    1080.0     2160.0
# CPU Frequency          0.9       2.0       2.5       2.7        3.6
# Memory Amount       8000.0  256000.0  256000.0  512000.0  2000000.0
# Android                NaN       NaN       NaN       NaN        NaN
# Chrome OS              NaN       NaN       NaN       NaN        NaN
# Linux                  NaN       NaN       NaN       NaN        NaN
# Mac OS X               NaN       NaN       NaN       NaN        NaN
# No OS                  NaN       NaN       NaN       NaN        NaN
# Windows 10             NaN       NaN       NaN       NaN        NaN
# Windows 10 S           NaN       NaN       NaN       NaN        NaN
# Windows 7              NaN       NaN       NaN       NaN        NaN
# macOS                  NaN       NaN       NaN       NaN        NaN
# AMD_CPU                NaN       NaN       NaN       NaN        NaN
# Intel_CPU              NaN       NaN       NaN       NaN        NaN
# Samsung_CPU            NaN       NaN       NaN       NaN        NaN
# AMD_GPU                NaN       NaN       NaN       NaN        NaN
# ARM_GPU                NaN       NaN       NaN       NaN        NaN
# Intel_GPU              NaN       NaN       NaN       NaN        NaN
# Nvidia_GPU             NaN       NaN       NaN       NaN        NaN
# Flash_MEM              NaN       NaN       NaN       NaN        NaN
# HDD_MEM                NaN       NaN       NaN       NaN        NaN
# Hybrid_MEM             NaN       NaN       NaN       NaN        NaN
# SSD_MEM                NaN       NaN       NaN       NaN        NaN

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 15))
sns.heatmap(df.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
target_correlations = df.corr()['Price_euros'].apply(abs).sort_values()

# %%
target_correlations
# Out:
# Xiaomi                0.000776
# Asus                  0.010376
# Mac OS X              0.015656
# Huawei                0.016851
# Windows 10 S          0.018312
# ARM_GPU               0.018431
# Samsung_CPU           0.018431
# Fujitsu               0.027135
# Lenovo                0.029007
# Samsung               0.034584
# Google                0.038086
# Android               0.038700
# Hybrid_MEM            0.039386
# Toshiba               0.040339
# HP                    0.041291
# Microsoft             0.047562
# Dell                  0.048509
# Chuwi                 0.055646
# LG                    0.067053
# laptop_ID             0.067830
# Inches                0.068197
# Vero                  0.071972
# 2 in 1 Convertible    0.072675
# Apple                 0.080688
# Mediacom              0.087161
# macOS                 0.089928
# Netbook               0.097572
# Chrome OS             0.118684
# Memory Amount         0.122365
# Windows 10            0.137048
# Windows 7             0.152381
# Linux                 0.162060
# No OS                 0.177094
# MSI                   0.180100
# AMD_CPU               0.180111
# Intel_CPU             0.181127
# Intel_GPU             0.184205
# AMD_GPU               0.199415
# Acer                  0.208349
# Weight                0.210370
# Flash_MEM             0.210823
# Razer                 0.233756
# Workstation           0.249752
# Ultrabook             0.255658
# Nvidia_GPU            0.348797
# Gaming                0.375789
# HDD_MEM               0.426121
# CPU Frequency         0.430293
# SSD_MEM               0.513609
# Notebook              0.549248
# Screen Height         0.552809
# Screen Width          0.556529
# Ram                   0.743007
# Price_euros           1.000000
# Name: Price_euros, dtype: float64

# %%
selected_features = target_correlations[-25:].index

# %%
selected_features = list(selected_features)

# %%
selected_features
# Out:
# ['Windows 10',
#  'Windows 7',
#  'Linux',
#  'No OS',
#  'MSI',
#  'AMD_CPU',
#  'Intel_CPU',
#  'Intel_GPU',
#  'AMD_GPU',
#  'Acer',
#  'Weight',
#  'Flash_MEM',
#  'Razer',
#  'Workstation',
#  'Ultrabook',
#  'Nvidia_GPU',
#  'Gaming',
#  'HDD_MEM',
#  'CPU Frequency',
#  'SSD_MEM',
#  'Notebook',
#  'Screen Height',
#  'Screen Width',
#  'Ram',
#  'Price_euros']

# %%
limited_df = df[selected_features]

# %%
limited_df
# Out:
#       Windows 10  Windows 7  Linux  No OS    MSI  AMD_CPU  Intel_CPU  \
# 0          False      False  False  False  False    False       True
# 1          False      False  False  False  False    False       True
# 2          False      False  False   True  False    False       True
# 3          False      False  False  False  False    False       True
# 4          False      False  False  False  False    False       True
# ...          ...        ...    ...    ...    ...      ...        ...
# 1298        True      False  False  False  False    False       True
# 1299        True      False  False  False  False    False       True
# 1300        True      False  False  False  False    False       True
# 1301        True      False  False  False  False    False       True
# 1302        True      False  False  False  False    False       True
#
#       Intel_GPU  AMD_GPU   Acer  Weight  Flash_MEM  Razer  Workstation  \
# 0          True    False  False    1.37      False  False        False
# 1          True    False  False    1.34       True  False        False
# 2          True    False  False    1.86      False  False        False
# 3         False     True  False    1.83      False  False        False
# 4          True    False  False    1.37      False  False        False
# ...         ...      ...    ...     ...        ...    ...          ...
# 1298       True    False  False    1.80      False  False        False
# 1299       True    False  False    1.30      False  False        False
# 1300       True    False  False    1.50       True  False        False
# 1301      False     True  False    2.19      False  False        False
# 1302       True    False  False    2.20      False  False        False
#
#       Ultrabook  Nvidia_GPU  Gaming  HDD_MEM  CPU Frequency  SSD_MEM  \
# 0          True       False   False    False            2.3     True
# 1          True       False   False    False            1.8    False
# 2         False       False   False    False            2.5     True
# 3          True       False   False    False            2.7     True
# 4          True       False   False    False            3.1     True
# ...         ...         ...     ...      ...            ...      ...
# 1298      False       False   False    False            2.5     True
# 1299      False       False   False    False            2.5     True
# 1300      False       False   False    False            1.6    False
# 1301      False       False   False     True            2.5    False
# 1302      False       False   False     True            1.6    False
#
#       Notebook  Screen Height  Screen Width  Ram  Price_euros
# 0        False           1600          2560    8      1339.69
# 1        False            900          1440    8       898.94
# 2         True           1080          1920    8       575.00
# 3        False           1800          2880   16      2537.45
# 4        False           1600          2560    8      1803.60
# ...        ...            ...           ...  ...          ...
# 1298     False           1080          1920    4       638.00
# 1299     False           1800          3200   16      1499.00
# 1300      True            768          1366    2       229.00
# 1301      True            768          1366    6       764.00
# 1302      True            768          1366    4       369.00
#
# [1303 rows x 25 columns]

# %%
plt.figure(figsize=(18, 15))
sns.heatmap(limited_df.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Modelling

# %%
X, y = limited_df.drop("Price_euros", axis=1), limited_df["Price_euros"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### 1. Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Initialize the model
linear_reg = LinearRegression()

# Fit the model to the training data
linear_reg.fit(X_train_scaled, y_train)

# Predict on the test data
y_pred_linear = linear_reg.predict(X_test_scaled)

# Evaluate the model
rmse_linear = np.sqrt(mean_squared_error(y_test, y_pred_linear))
r2_linear = r2_score(y_test, y_pred_linear)

print(f"Linear Regression:\n RMSE: {rmse_linear:.4f}\n R²: {r2_linear:.4f}\n")
# Out:
# Linear Regression:
#  RMSE: 334.3718
#  R²: 0.7657

# %% [markdown]
# ### 2. **Ridge Regression**

# %%
from sklearn.linear_model import Ridge

# Initialize the model
ridge_reg = Ridge(alpha=1.0)

# Fit the model to the training data
ridge_reg.fit(X_train_scaled, y_train)

# Predict on the test data
y_pred_ridge = ridge_reg.predict(X_test_scaled)

# Evaluate the model
rmse_ridge = np.sqrt(mean_squared_error(y_test, y_pred_ridge))
r2_ridge = r2_score(y_test, y_pred_ridge)

print(f"Ridge Regression:\n RMSE: {rmse_ridge:.4f}\n R²: {r2_ridge:.4f}\n")
# Out:
# Ridge Regression:
#  RMSE: 334.4962
#  R²: 0.7655

# %% [markdown]
# ### 3. **Support Vector Regression (SVR)**

# %%
from sklearn.svm import SVR

# Initialize the model
svr_reg = SVR(kernel='rbf')

# Fit the model to the training data
svr_reg.fit(X_train_scaled, y_train)

# Predict on the test data
y_pred_svr = svr_reg.predict(X_test_scaled)

# Evaluate the model
rmse_svr = np.sqrt(mean_squared_error(y_test, y_pred_svr))
r2_svr = r2_score(y_test, y_pred_svr)

print(f"Support Vector Regression:\n RMSE: {rmse_svr:.4f}\n R²: {r2_svr:.4f}\n")
# Out:
# Support Vector Regression:
#  RMSE: 669.9551
#  R²: 0.0594

# %% [markdown]
# ### 4. **Gradient Boosting Regressor**

# %%
from sklearn.ensemble import GradientBoostingRegressor

# Initialize the model
gb_reg = GradientBoostingRegressor()

# Fit the model to the training data
gb_reg.fit(X_train_scaled, y_train)

# Predict on the test data
y_pred_gb = gb_reg.predict(X_test_scaled)

# Evaluate the model
rmse_gb = np.sqrt(mean_squared_error(y_test, y_pred_gb))
r2_gb = r2_score(y_test, y_pred_gb)

print(f"Gradient Boosting Regressor:\n RMSE: {rmse_gb:.4f}\n R²: {r2_gb:.4f}\n")

# %% [markdown]
# ### 5. **K-Nearest Neighbors (KNN)**

# %%
from sklearn.neighbors import KNeighborsRegressor

# Initialize the model
knn_reg = KNeighborsRegressor(n_neighbors=5)

# Fit the model to the training data
knn_reg.fit(X_train_scaled, y_train)

# Predict on the test data
y_pred_knn = knn_reg.predict(X_test_scaled)

# Evaluate the model
rmse_knn = np.sqrt(mean_squared_error(y_test, y_pred_knn))
r2_knn = r2_score(y_test, y_pred_knn)

print(f"K-Nearest Neighbors:\n RMSE: {rmse_knn:.4f}\n R²: {r2_knn:.4f}\n")

# %% [markdown]
# ### 6. **Random Forest Regressor**

# %%
from sklearn.ensemble import RandomForestRegressor

# Initialize the model
forest_reg = RandomForestRegressor()

# Fit the model to the training data
forest_reg.fit(X_train_scaled, y_train)

# Predict on the test data
y_pred_forest = forest_reg.predict(X_test_scaled)

# Evaluate the model
rmse_forest = np.sqrt(mean_squared_error(y_test, y_pred_forest))
r2_forest = r2_score(y_test, y_pred_forest)

print(f"Random Forest Regressor:\n RMSE: {rmse_forest:.4f}\n R²: {r2_forest:.4f}\n")

# %% [markdown]
# ### 7. **Decision Tree Regressor**

# %%
from sklearn.tree import DecisionTreeRegressor

# Initialize the model
tree_reg = DecisionTreeRegressor()

# Fit the model to the training data
tree_reg.fit(X_train_scaled, y_train)

# Predict on the test data
y_pred_tree = tree_reg.predict(X_test_scaled)

# Evaluate the model
rmse_tree = np.sqrt(mean_squared_error(y_test, y_pred_tree))
r2_tree = r2_score(y_test, y_pred_tree)

print(f"Decision Tree Regressor:\n RMSE: {rmse_tree:.4f}\n R²: {r2_tree:.4f}\n")

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Assuming limited_df is your DataFrame containing the features and target variable
X, y = limited_df.drop("Price_euros", axis=1), limited_df["Price_euros"]

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# Scale the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize regression models
models = {
    "Linear Regression": LinearRegression(),
    "Ridge Regression": Ridge(alpha=1.0),
    "Support Vector Regression": SVR(kernel='rbf'),
    "Gradient Boosting Regressor": GradientBoostingRegressor(),
    "K-Nearest Neighbors": KNeighborsRegressor(n_neighbors=5),
    "Random Forest Regressor": RandomForestRegressor(),
    "Decision Tree Regressor": DecisionTreeRegressor()
}

best_model = None
best_rmse = float("inf")
best_r2 = float("-inf")

# Train each model and evaluate its performance
for name, model in models.items():
    # Fit the model to the training data
    model.fit(X_train_scaled, y_train)
    
    # Predict on the test data
    y_pred = model.predict(X_test_scaled)
    
    # Evaluate the model using RMSE and R²
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    
    print(f"{name}:\n RMSE: {rmse:.4f}\n R²: {r2:.4f}\n")
    
    # Select the best model based on RMSE
    if rmse < best_rmse:
        best_rmse = rmse
        best_r2 = r2
        best_model = name

print(f"\nBest Model: {best_model}\n Best RMSE: {best_rmse:.4f}\n Best R²: {best_r2:.4f}")
# Out:
# Linear Regression:
#  RMSE: 360.5972
#  R²: 0.7721
#
# Ridge Regression:
#  RMSE: 360.5028
#  R²: 0.7722
#
# Support Vector Regression:
#  RMSE: 737.7544
#  R²: 0.0461
#
# Gradient Boosting Regressor:
#  RMSE: 281.9059
#  R²: 0.8607
#
# K-Nearest Neighbors:
#  RMSE: 402.6021
#  R²: 0.7159
#
# Random Forest Regressor:
#  RMSE: 309.2424
#  R²: 0.8324
#
# Decision Tree Regressor:
#  RMSE: 398.6861
#  R²: 0.7214
#
#
# Best Model: Gradient Boosting Regressor
#  Best RMSE: 281.9059
#  Best R²: 0.8607
